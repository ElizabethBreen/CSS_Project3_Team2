# %% [markdown]
# # Project 3
# #### Computational Social Science, Fall 2020
# #### Team 2: Elizabeth Breen, Madeleine Parker, Mahader Tamene

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import confusion_matrix
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import warnings
from sklearn.exceptions import DataConversionWarning
warnings.filterwarnings(action='ignore')
from sklearn.metrics import accuracy_score
from sklearn import tree
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from matplotlib import pyplot




# Make sure to import other libraries that will be necessary for training models!

# %%
# Inspections Data 2011 - 2013
chicago_inspections_2011_to_2013 = pd.read_csv("data/Chicago Inspections 2011-2013.csv")

# Inspections Data 2014
chicago_inspections_2014 = pd.read_csv("data/Chicago Inspections 2014.csv")

# %%
# Look at the inspections data
chicago_inspections_2011_to_2013.head()
# Out:
#    Inspection_ID Inspection_Date                      DBA_Name  \
# 0         269961      2013-01-31                    SEVEN STAR
# 1         507211      2011-10-18                  PANERA BREAD
# 2         507212      2011-10-18      LITTLE QUIAPO RESTAURANT
# 3         507216      2011-10-19  SERGIO'S TAQUERIA PIZZA INC.
# 4         507219      2011-10-20         TARGET STORE # T-2079
#
#                    AKA_Name  License  Facility_Type             Risk  \
# 0                SEVEN STAR    30790  Grocery Store     Risk 3 (Low)
# 1              PANERA BREAD  1475890     Restaurant    Risk 1 (High)
# 2  LITTLE QUIAPO RESTAURANT  1740130     Restaurant    Risk 1 (High)
# 3   SERGIO'S TAQUERIA PIZZA  1447363     Restaurant    Risk 1 (High)
# 4                    TARGET  1679459     Restaurant  Risk 2 (Medium)
#
#                  Address     City State      Zip Inspection_Type Results  \
# 0       3352 N BROADWAY   CHICAGO    IL  60657.0         Canvass    Pass
# 1    6059 N LINCOLN AVE   CHICAGO    IL  60659.0         Canvass    Pass
# 2   6259 N MCCORMICK RD   CHICAGO    IL  60659.0         Canvass    Fail
# 3  3253 W BRYN MAWR AVE   CHICAGO    IL  60659.0         Canvass    Pass
# 4   2112 W PETERSON AVE   CHICAGO    IL  60659.0         Canvass    Fail
#
#     Latitude  Longitude                                  Location  \
# 0  41.943359 -87.644999  (41.943359344775146, -87.64499875300952)
# 1  41.991919 -87.709631   (41.99191947239194, -87.70963133440333)
# 2  41.995632 -87.712707   (41.99563177556418, -87.71270678169132)
# 3  41.982933 -87.710982  (41.982933189164974, -87.71098225381141)
# 4  41.990729 -87.682979   (41.99072921796059, -87.68297945359863)
#
#   Facility_Type_Clean  criticalCount  seriousCount  minorCount  pass_flag  \
# 0               Other              0             0           2          1
# 1          Restaurant              0             0           3          1
# 2          Restaurant              0             2           6          0
# 3          Restaurant              0             0           6          1
# 4          Restaurant              0             2           6          0
#
#    fail_flag  pastFail  pastCritical  pastSerious  pastMinor  timeSinceLast  \
# 0          0         0             0            0          0            2.0
# 1          0         0             0            0          0            2.0
# 2          1         0             0            0          0            2.0
# 3          0         0             0            0          0            2.0
# 4          1         0             0            0          0            2.0
#
#    firstRecord                ID  LICENSE_ID  ACCOUNT_NUMBER  \
# 0            1    30790-20110416   2081412.0         63759.0
# 1            1  1475890-20110416   2081695.0        207283.0
# 2            1  1740130-20110216   2070145.0          3107.0
# 3            1  1447363-20110216   2071895.0        270993.0
# 4            1  1679459-20100216   2009972.0         15538.0
#
#                      LEGAL_NAME        DOING_BUSINESS_AS_NAME  \
# 0            VIRGINIA DELA ROSA                    SEVEN STAR
# 1                   PANERA, LLC                  PANERA BREAD
# 2                ENELITA GARCIA      LITTLE QUIAPO RESTAURANT
# 3  SERGIO'S TAZUERIA PIZZA INC.  SERGIO'S TAQUERIA PIZZA INC.
# 4            TARGET CORPORATION         TARGET STORE # T-2079
#
#                  ADDRESS     CITY STATE  ZIP_CODE  WARD  PRECINCT  \
# 0    3352 N BROADWAY   1  CHICAGO    IL   60657.0  44.0      33.0
# 1  6059 N LINCOLN AVE  C  CHICAGO    IL   60659.0  50.0      23.0
# 2    6259 N MCCORMICK RD  CHICAGO    IL   60659.0  50.0      25.0
# 3   3253 W BRYN MAWR AVE  CHICAGO    IL   60659.0  39.0      48.0
# 4    2112 W PETERSON AVE  CHICAGO    IL   60659.0  40.0      18.0
#
#   WARD_PRECINCT  POLICE_DISTRICT  LICENSE_CODE        LICENSE_DESCRIPTION  \
# 0         44-33             19.0        1006.0  Retail Food Establishment
# 1         50-23             24.0        1006.0  Retail Food Establishment
# 2         50-25             17.0        1006.0  Retail Food Establishment
# 3         39-48             17.0        1006.0  Retail Food Establishment
# 4         40-18             24.0        1006.0  Retail Food Establishment
#
#   BUSINESS_ACTIVITY_ID                 BUSINESS_ACTIVITY  LICENSE_NUMBER  \
# 0                  775  Retail Sales of Perishable Foods         30790.0
# 1                  775  Retail Sales of Perishable Foods       1475890.0
# 2                  775  Retail Sales of Perishable Foods       1740130.0
# 3                  775  Retail Sales of Perishable Foods       1447363.0
# 4                  775  Retail Sales of Perishable Foods       1679459.0
#
#   APPLICATION_TYPE LICENSE_TERM_START_DATE LICENSE_TERM_EXPIRATION_DATE  \
# 0            RENEW              2011-04-16                   2013-04-15
# 1            RENEW              2011-04-16                   2013-04-15
# 2            RENEW              2011-02-16                   2013-02-15
# 3            RENEW              2011-02-16                   2013-02-15
# 4            RENEW              2010-02-16                   2012-02-15
#
#   LICENSE_STATUS   LATITUDE  LONGITUDE     minDate     maxDate  \
# 0            AAI  41.943359 -87.644999  2002-02-16  2015-04-15
# 1            AAI  41.991919 -87.709631  2004-05-05  2019-04-15
# 2            AAI  41.995632 -87.712707  2007-03-22  2017-02-15
# 3            AAI  41.982933 -87.710982  2003-12-31  2019-02-15
# 4            AAI  41.990729 -87.682979  2006-07-07  2018-02-15
#
#    ageAtInspection  consumption_on_premises_incidental_activity  tobacco  \
# 0        10.964384                                            0        1
# 1         7.457534                                            0        0
# 2         4.578082                                            0        0
# 3         7.805479                                            0        0
# 4         5.290411                                            0        0
#
#    package_goods  outdoor_patio  public_place_of_amusement  \
# 0              0              0                          0
# 1              0              0                          0
# 2              0              0                          0
# 3              0              0                          0
# 4              1              0                          0
#
#    limited_business_license  childrens_services_facility_license  tavern  \
# 0                         1                                    0       0
# 1                         0                                    0       0
# 2                         0                                    0       0
# 3                         0                                    0       0
# 4                         1                                    0       0
#
#    regulated_business_license  filling_station  caterers_liquor_license  \
# 0                           0                0                        0
# 1                           0                0                        0
# 2                           0                0                        0
# 3                           0                0                        0
# 4                           0                0                        0
#
#    mobile_food_license  precipIntensity  temperatureMax  windSpeed  humidity  \
# 0                    0         0.014587       53.496667  13.340000  0.900000
# 1                    0         0.001907       59.046667  13.016667  0.550000
# 2                    0         0.001907       59.046667  13.016667  0.550000
# 3                    0         0.002737       56.153333  10.863333  0.616667
# 4                    0         0.009987       52.730000  16.266667  0.690000
#
#    heat_burglary  heat_garbage  heat_sanitation  criticalFound
# 0      26.992376     12.768572        37.748787              0
# 1      13.976557     12.895485        15.412267              0
# 2      12.611239      8.004220         8.320330              0
# 3      35.906383     26.238645        38.186618              0
# 4       9.530785      3.401567         2.126788              0

# %%
# List column names
chicago_inspections_2011_to_2013.columns
#len(chicago_inspections_2011_to_2013.columns)
# 75 total columns
# Out:
# Index(['Inspection_ID', 'Inspection_Date', 'DBA_Name', 'AKA_Name', 'License',
#        'Facility_Type', 'Risk', 'Address', 'City', 'State', 'Zip',
#        'Inspection_Type', 'Results', 'Latitude', 'Longitude', 'Location',
#        'Facility_Type_Clean', 'criticalCount', 'seriousCount', 'minorCount',
#        'pass_flag', 'fail_flag', 'pastFail', 'pastCritical', 'pastSerious',
#        'pastMinor', 'timeSinceLast', 'firstRecord', 'ID', 'LICENSE_ID',
#        'ACCOUNT_NUMBER', 'LEGAL_NAME', 'DOING_BUSINESS_AS_NAME', 'ADDRESS',
#        'CITY', 'STATE', 'ZIP_CODE', 'WARD', 'PRECINCT', 'WARD_PRECINCT',
#        'POLICE_DISTRICT', 'LICENSE_CODE', 'LICENSE_DESCRIPTION',
#        'BUSINESS_ACTIVITY_ID', 'BUSINESS_ACTIVITY', 'LICENSE_NUMBER',
#        'APPLICATION_TYPE', 'LICENSE_TERM_START_DATE',
#        'LICENSE_TERM_EXPIRATION_DATE', 'LICENSE_STATUS', 'LATITUDE',
#        'LONGITUDE', 'minDate', 'maxDate', 'ageAtInspection',
#        'consumption_on_premises_incidental_activity', 'tobacco',
#        'package_goods', 'outdoor_patio', 'public_place_of_amusement',
#        'limited_business_license', 'childrens_services_facility_license',
#        'tavern', 'regulated_business_license', 'filling_station',
#        'caterers_liquor_license', 'mobile_food_license', 'precipIntensity',
#        'temperatureMax', 'windSpeed', 'humidity', 'heat_burglary',
#        'heat_garbage', 'heat_sanitation', 'criticalFound'],
#       dtype='object')

# %%
# Drop column names related to geography, identification, and pass/fail flags that perfectly predict the outcome
chicago_inspections_2011_to_2013.drop(columns = ['AKA_Name', 
                                                 'License',
                                                'Address',
                                                'City',
                                                'State',
                                                'Zip',
                                                'Latitude',
                                                'Longitude',
                                                'Location',
                                                'ID',
                                                'LICENSE_ID',
                                                 'LICENSE_TERM_START_DATE',
                                                 'LICENSE_TERM_EXPIRATION_DATE',
                                                 'LICENSE_STATUS',
                                                'ACCOUNT_NUMBER',
                                                'LEGAL_NAME',
                                                'DOING_BUSINESS_AS_NAME',
                                                'ADDRESS',
                                                'CITY',
                                                'STATE',
                                                'ZIP_CODE',
                                                'WARD',
                                                'PRECINCT',
                                                'LICENSE_CODE',
                                                'BUSINESS_ACTIVITY_ID',
                                                'BUSINESS_ACTIVITY',
                                                'LICENSE_NUMBER',
                                                'LATITUDE',
                                                'LONGITUDE',
                                                'pass_flag',
                                                'fail_flag',
                                                'criticalCount', 
                                                'seriousCount',
                                                'minorCount',
                                                'criticalFound'],inplace = True)

chicago_inspections_2011_to_2013.set_index(['Inspection_ID', 'DBA_Name'], inplace = True)

# %%
# Convert the Inspection Date to a datetime format
chicago_inspections_2011_to_2013['Inspection_Date'] = pd.to_datetime(chicago_inspections_2011_to_2013['Inspection_Date'], infer_datetime_format=True)

# %%
#len(chicago_inspections_2011_to_2013.columns)
#38 columns

# %% [markdown]
# ## Visualization

# %% [markdown]
# <b> What do inspections look like over time? </b>
#
# At first glance, the values seem to fluctuate with no real pattern. We do see dips around Jan and July of each year and peaks in April and October.  2013 also has overall more inspections than 2012.

# %%
# Visualize Inspections Over Time
chicago_inspections_2011_to_2013['Inspection_MonthYear'] = chicago_inspections_2011_to_2013['Inspection_Date'].dt.to_period('M')
counts_by_day = chicago_inspections_2011_to_2013.groupby('Inspection_MonthYear').count().rename(columns = {'Facility_Type': 'Count'})['Count'].reset_index()
counts_by_day.set_index(["Inspection_MonthYear"], inplace = True)
counts_by_day.plot(title = "Inspections by Month and Year")
# Out:
# <AxesSubplot:title={'center':'Inspections by Month and Year'}, xlabel='Inspection_MonthYear'>

# %% [markdown]
# <b>What do the results look like?</b>
#
# A good majority of the facilities passed inspection (68%), with few failing (20%) and a small percentage passing w/ conditions (12%).

# %%
# Inspection Results
sns.catplot(data = chicago_inspections_2011_to_2013,
           x = "Results",
           kind = "count")

plt.title("Inspection Results")
plt.show()

# %% [markdown]
# <b> What if we separate by facility type? </b>
#
# Restaurants are the most common facility type across all inspection results.

# %%
# Inspection Results by Facility Type (Restaurant or Not)
sns.catplot(data = chicago_inspections_2011_to_2013,
           x = "Results",
           kind = "count",
           hue = 'Facility_Type_Clean')

plt.title("Inspection Results by Facility Type")
plt.show()

# %%
# Is there a trend in age of restaurant vs # of failures?

age = round(chicago_inspections_2011_to_2013['ageAtInspection'])

chicago_inspections_2011_to_2013['age'] = age


x = chicago_inspections_2011_to_2013['age']
plt.hist(x, density=True, bins=20)  # `density=False` would make counts
plt.ylabel('Count')
plt.xlabel('Age of Restaurant at Inspection');

# %%
# recode into 3 age bins, new, mid, old

def age_groups(series):
    if series < 5:
        return "young"
    elif 5 <= series < 9:
        return "middle"
    elif 9 <= series:
        return "old"
    
chicago_inspections_2011_to_2013['age_groups'] = chicago_inspections_2011_to_2013['age'].apply(age_groups)
chicago_inspections_2011_to_2013['age_groups'].value_counts(sort=False)
# Out:
# young     5684
# middle    3440
# old       6640
# Name: age_groups, dtype: int64

# %%
# Inspection Results by Age of Facility
sns.catplot(data = chicago_inspections_2011_to_2013,
           x = "age_groups",
           kind = "count",
           hue = 'Results')

plt.title("Inspection Results by Facility Age")
plt.show()

# %% [markdown]
# ## Preprocess Data

# %%
# Drop datetime info
chicago_inspections_2011_to_2013 = chicago_inspections_2011_to_2013.dropna().drop(['Inspection_Date',
                                      'minDate',
                                      'maxDate',
                                      'Inspection_MonthYear'],
                                      axis = 1)

# %%
# Set target variable. 
y = chicago_inspections_2011_to_2013['Results']
## Comment out the following code if you don't want to binarize the target variable
y = y.replace({'Pass w/ Conditions': 'Pass'})
lb_style = LabelBinarizer()
y = lb_style.fit_transform(y)
# Recode 0s and 1s so 1s are "Fail"
y = np.where(y == 1, 0 ,1)

# All other features in X
X = chicago_inspections_2011_to_2013.drop(columns = ['Results'])
X = pd.get_dummies(X)

# %%
X.head()
# Out:
#                                             pastFail  pastCritical  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                           0             0
# 507211        PANERA BREAD                         0             0
# 507212        LITTLE QUIAPO RESTAURANT             0             0
# 507216        SERGIO'S TAQUERIA PIZZA INC.         0             0
# 507219        TARGET STORE # T-2079                0             0
#
#                                             pastSerious  pastMinor  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                              0          0
# 507211        PANERA BREAD                            0          0
# 507212        LITTLE QUIAPO RESTAURANT                0          0
# 507216        SERGIO'S TAQUERIA PIZZA INC.            0          0
# 507219        TARGET STORE # T-2079                   0          0
#
#                                             timeSinceLast  firstRecord  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                              2.0            1
# 507211        PANERA BREAD                            2.0            1
# 507212        LITTLE QUIAPO RESTAURANT                2.0            1
# 507216        SERGIO'S TAQUERIA PIZZA INC.            2.0            1
# 507219        TARGET STORE # T-2079                   2.0            1
#
#                                             POLICE_DISTRICT  ageAtInspection  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                               19.0        10.964384
# 507211        PANERA BREAD                             24.0         7.457534
# 507212        LITTLE QUIAPO RESTAURANT                 17.0         4.578082
# 507216        SERGIO'S TAQUERIA PIZZA INC.             17.0         7.805479
# 507219        TARGET STORE # T-2079                    24.0         5.290411
#
#                                             consumption_on_premises_incidental_activity  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                              0
# 507211        PANERA BREAD                                                            0
# 507212        LITTLE QUIAPO RESTAURANT                                                0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                            0
# 507219        TARGET STORE # T-2079                                                   0
#
#                                             tobacco  package_goods  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                          1              0
# 507211        PANERA BREAD                        0              0
# 507212        LITTLE QUIAPO RESTAURANT            0              0
# 507216        SERGIO'S TAQUERIA PIZZA INC.        0              0
# 507219        TARGET STORE # T-2079               0              1
#
#                                             outdoor_patio  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                0
# 507211        PANERA BREAD                              0
# 507212        LITTLE QUIAPO RESTAURANT                  0
# 507216        SERGIO'S TAQUERIA PIZZA INC.              0
# 507219        TARGET STORE # T-2079                     0
#
#                                             public_place_of_amusement  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                            0
# 507211        PANERA BREAD                                          0
# 507212        LITTLE QUIAPO RESTAURANT                              0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                          0
# 507219        TARGET STORE # T-2079                                 0
#
#                                             limited_business_license  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                           1
# 507211        PANERA BREAD                                         0
# 507212        LITTLE QUIAPO RESTAURANT                             0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                         0
# 507219        TARGET STORE # T-2079                                1
#
#                                             childrens_services_facility_license  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                      0
# 507211        PANERA BREAD                                                    0
# 507212        LITTLE QUIAPO RESTAURANT                                        0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                    0
# 507219        TARGET STORE # T-2079                                           0
#
#                                             tavern  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                         0
# 507211        PANERA BREAD                       0
# 507212        LITTLE QUIAPO RESTAURANT           0
# 507216        SERGIO'S TAQUERIA PIZZA INC.       0
# 507219        TARGET STORE # T-2079              0
#
#                                             regulated_business_license  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                             0
# 507211        PANERA BREAD                                           0
# 507212        LITTLE QUIAPO RESTAURANT                               0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                           0
# 507219        TARGET STORE # T-2079                                  0
#
#                                             filling_station  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                  0
# 507211        PANERA BREAD                                0
# 507212        LITTLE QUIAPO RESTAURANT                    0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                0
# 507219        TARGET STORE # T-2079                       0
#
#                                             caterers_liquor_license  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                          0
# 507211        PANERA BREAD                                        0
# 507212        LITTLE QUIAPO RESTAURANT                            0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                        0
# 507219        TARGET STORE # T-2079                               0
#
#                                             mobile_food_license  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                      0
# 507211        PANERA BREAD                                    0
# 507212        LITTLE QUIAPO RESTAURANT                        0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                    0
# 507219        TARGET STORE # T-2079                           0
#
#                                             precipIntensity  temperatureMax  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                           0.014587       53.496667
# 507211        PANERA BREAD                         0.001907       59.046667
# 507212        LITTLE QUIAPO RESTAURANT             0.001907       59.046667
# 507216        SERGIO'S TAQUERIA PIZZA INC.         0.002737       56.153333
# 507219        TARGET STORE # T-2079                0.009987       52.730000
#
#                                             windSpeed  humidity  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                    13.340000  0.900000
# 507211        PANERA BREAD                  13.016667  0.550000
# 507212        LITTLE QUIAPO RESTAURANT      13.016667  0.550000
# 507216        SERGIO'S TAQUERIA PIZZA INC.  10.863333  0.616667
# 507219        TARGET STORE # T-2079         16.266667  0.690000
#
#                                             heat_burglary  heat_garbage  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                        26.992376     12.768572
# 507211        PANERA BREAD                      13.976557     12.895485
# 507212        LITTLE QUIAPO RESTAURANT          12.611239      8.004220
# 507216        SERGIO'S TAQUERIA PIZZA INC.      35.906383     26.238645
# 507219        TARGET STORE # T-2079              9.530785      3.401567
#
#                                             heat_sanitation   age  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                          37.748787  11.0
# 507211        PANERA BREAD                        15.412267   7.0
# 507212        LITTLE QUIAPO RESTAURANT             8.320330   5.0
# 507216        SERGIO'S TAQUERIA PIZZA INC.        38.186618   8.0
# 507219        TARGET STORE # T-2079                2.126788   5.0
#
#                                             Facility_Type_1005  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                     0
# 507211        PANERA BREAD                                   0
# 507212        LITTLE QUIAPO RESTAURANT                       0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                   0
# 507219        TARGET STORE # T-2079                          0
#
#                                             Facility_Type_1023 CHILDERN'S SERVICE FACILITY  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                                 0
# 507211        PANERA BREAD                                                               0
# 507212        LITTLE QUIAPO RESTAURANT                                                   0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                               0
# 507219        TARGET STORE # T-2079                                                      0
#
#                                             Facility_Type_1023 CHILDERN'S SERVICE S FACILITY  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                                   0
# 507211        PANERA BREAD                                                                 0
# 507212        LITTLE QUIAPO RESTAURANT                                                     0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                                 0
# 507219        TARGET STORE # T-2079                                                        0
#
#                                             Facility_Type_1023 CHILDERN'S SERVICES FACILITY  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                                  0
# 507211        PANERA BREAD                                                                0
# 507212        LITTLE QUIAPO RESTAURANT                                                    0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                                0
# 507219        TARGET STORE # T-2079                                                       0
#
#                                             Facility_Type_1023-CHILDREN'S SERVICES FACILITY  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                                  0
# 507211        PANERA BREAD                                                                0
# 507212        LITTLE QUIAPO RESTAURANT                                                    0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                                0
# 507219        TARGET STORE # T-2079                                                       0
#
#                                             Facility_Type_A-Not-For-Profit Chef Training Program  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                                    0
# 507211        PANERA BREAD                                                                  0
# 507212        LITTLE QUIAPO RESTAURANT                                                      0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                                  0
# 507219        TARGET STORE # T-2079                                                         0
#
#                                             Facility_Type_ASSISTED LIVING  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                0
# 507211        PANERA BREAD                                              0
# 507212        LITTLE QUIAPO RESTAURANT                                  0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                              0
# 507219        TARGET STORE # T-2079                                     0
#
#                                             Facility_Type_BAKERY  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                       0
# 507211        PANERA BREAD                                     0
# 507212        LITTLE QUIAPO RESTAURANT                         0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                     0
# 507219        TARGET STORE # T-2079                            0
#
#                                             Facility_Type_BAKERY/DELI  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                            0
# 507211        PANERA BREAD                                          0
# 507212        LITTLE QUIAPO RESTAURANT                              0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                          0
# 507219        TARGET STORE # T-2079                                 0
#
#                                             Facility_Type_BANQUET  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                        0
# 507211        PANERA BREAD                                      0
# 507212        LITTLE QUIAPO RESTAURANT                          0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                      0
# 507219        TARGET STORE # T-2079                             0
#
#                                             Facility_Type_BANQUET FACILITY  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                 0
# 507211        PANERA BREAD                                               0
# 507212        LITTLE QUIAPO RESTAURANT                                   0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                               0
# 507219        TARGET STORE # T-2079                                      0
#
#                                             Facility_Type_BANQUET HALL  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                             0
# 507211        PANERA BREAD                                           0
# 507212        LITTLE QUIAPO RESTAURANT                               0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                           0
# 507219        TARGET STORE # T-2079                                  0
#
#                                             Facility_Type_BAR  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                    0
# 507211        PANERA BREAD                                  0
# 507212        LITTLE QUIAPO RESTAURANT                      0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                  0
# 507219        TARGET STORE # T-2079                         0
#
#                                             Facility_Type_BAR/GRILL  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                          0
# 507211        PANERA BREAD                                        0
# 507212        LITTLE QUIAPO RESTAURANT                            0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                        0
# 507219        TARGET STORE # T-2079                               0
#
#                                             Facility_Type_BEFORE AND AFTER SCHOOL PROGRAM  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                                0
# 507211        PANERA BREAD                                                              0
# 507212        LITTLE QUIAPO RESTAURANT                                                  0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                              0
# 507219        TARGET STORE # T-2079                                                     0
#
#                                             Facility_Type_BEVERAGE/SILVERWARE WAREHOUSE  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                              0
# 507211        PANERA BREAD                                                            0
# 507212        LITTLE QUIAPO RESTAURANT                                                0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                            0
# 507219        TARGET STORE # T-2079                                                   0
#
#                                             Facility_Type_Bakery  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                       0
# 507211        PANERA BREAD                                     0
# 507212        LITTLE QUIAPO RESTAURANT                         0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                     0
# 507219        TARGET STORE # T-2079                            0
#
#                                             Facility_Type_Banquet Dining  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                               0
# 507211        PANERA BREAD                                             0
# 507212        LITTLE QUIAPO RESTAURANT                                 0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                             0
# 507219        TARGET STORE # T-2079                                    0
#
#                                             Facility_Type_Banquet rooms  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                              0
# 507211        PANERA BREAD                                            0
# 507212        LITTLE QUIAPO RESTAURANT                                0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                            0
# 507219        TARGET STORE # T-2079                                   0
#
#                                             Facility_Type_CAFE/STORE  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                           0
# 507211        PANERA BREAD                                         0
# 507212        LITTLE QUIAPO RESTAURANT                             0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                         0
# 507219        TARGET STORE # T-2079                                0
#
#                                             Facility_Type_CAFETERIA  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                          0
# 507211        PANERA BREAD                                        0
# 507212        LITTLE QUIAPO RESTAURANT                            0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                        0
# 507219        TARGET STORE # T-2079                               0
#
#                                             Facility_Type_CANDY STORE  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                            0
# 507211        PANERA BREAD                                          0
# 507212        LITTLE QUIAPO RESTAURANT                              0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                          0
# 507219        TARGET STORE # T-2079                                 0
#
#                                             Facility_Type_CANDY/GELATO  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                             0
# 507211        PANERA BREAD                                           0
# 507212        LITTLE QUIAPO RESTAURANT                               0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                           0
# 507219        TARGET STORE # T-2079                                  0
#
#                                             Facility_Type_CATERING COMPANY  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                 0
# 507211        PANERA BREAD                                               0
# 507212        LITTLE QUIAPO RESTAURANT                                   0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                               0
# 507219        TARGET STORE # T-2079                                      0
#
#                                             Facility_Type_CATERING/CAFE  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                              0
# 507211        PANERA BREAD                                            0
# 507212        LITTLE QUIAPO RESTAURANT                                0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                            0
# 507219        TARGET STORE # T-2079                                   0
#
#                                             Facility_Type_CHARITY AID KITCHEN  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                    0
# 507211        PANERA BREAD                                                  0
# 507212        LITTLE QUIAPO RESTAURANT                                      0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                  0
# 507219        TARGET STORE # T-2079                                         0
#
#                                             Facility_Type_CHINESE HERBS  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                              0
# 507211        PANERA BREAD                                            0
# 507212        LITTLE QUIAPO RESTAURANT                                0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                            0
# 507219        TARGET STORE # T-2079                                   0
#
#                                             Facility_Type_CITY OF CHICAGO COLLEGE  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                        0
# 507211        PANERA BREAD                                                      0
# 507212        LITTLE QUIAPO RESTAURANT                                          0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                      0
# 507219        TARGET STORE # T-2079                                             0
#
#                                             Facility_Type_COFFEE  SHOP  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                             0
# 507211        PANERA BREAD                                           0
# 507212        LITTLE QUIAPO RESTAURANT                               0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                           0
# 507219        TARGET STORE # T-2079                                  0
#
#                                             Facility_Type_COFFEE CART  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                            0
# 507211        PANERA BREAD                                          0
# 507212        LITTLE QUIAPO RESTAURANT                              0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                          0
# 507219        TARGET STORE # T-2079                                 0
#
#                                             Facility_Type_COFFEE KIOSK  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                             0
# 507211        PANERA BREAD                                           0
# 507212        LITTLE QUIAPO RESTAURANT                               0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                           0
# 507219        TARGET STORE # T-2079                                  0
#
#                                             Facility_Type_COFFEE SHOP  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                            0
# 507211        PANERA BREAD                                          0
# 507212        LITTLE QUIAPO RESTAURANT                              0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                          0
# 507219        TARGET STORE # T-2079                                 0
#
#                                             Facility_Type_COLD/FROZEN FOOD STORAGE  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                         0
# 507211        PANERA BREAD                                                       0
# 507212        LITTLE QUIAPO RESTAURANT                                           0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                       0
# 507219        TARGET STORE # T-2079                                              0
#
#                                             Facility_Type_COLLEGE  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                        0
# 507211        PANERA BREAD                                      0
# 507212        LITTLE QUIAPO RESTAURANT                          0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                      0
# 507219        TARGET STORE # T-2079                             0
#
#                                             Facility_Type_COMMISSARY FOR SOFT SERVE ICE CREAM TRUCKS  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                                    0
# 507211        PANERA BREAD                                                                  0
# 507212        LITTLE QUIAPO RESTAURANT                                                      0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                                  0
# 507219        TARGET STORE # T-2079                                                         0
#
#                                             Facility_Type_CONVENIENCE  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                            0
# 507211        PANERA BREAD                                          0
# 507212        LITTLE QUIAPO RESTAURANT                              0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                          0
# 507219        TARGET STORE # T-2079                                 0
#
#                                             Facility_Type_CONVENIENCE STORE  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                  0
# 507211        PANERA BREAD                                                0
# 507212        LITTLE QUIAPO RESTAURANT                                    0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                0
# 507219        TARGET STORE # T-2079                                       0
#
#                                             Facility_Type_CONVNIENCE STORE  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                 0
# 507211        PANERA BREAD                                               0
# 507212        LITTLE QUIAPO RESTAURANT                                   0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                               0
# 507219        TARGET STORE # T-2079                                      0
#
#                                             Facility_Type_CULINARY ARTS SCHOOL  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                     0
# 507211        PANERA BREAD                                                   0
# 507212        LITTLE QUIAPO RESTAURANT                                       0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                   0
# 507219        TARGET STORE # T-2079                                          0
#
#                                             Facility_Type_CULINARY SCHOOL  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                0
# 507211        PANERA BREAD                                              0
# 507212        LITTLE QUIAPO RESTAURANT                                  0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                              0
# 507219        TARGET STORE # T-2079                                     0
#
#                                             Facility_Type_CUSTOM POULTRY SLAUGHTER  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                         0
# 507211        PANERA BREAD                                                       0
# 507212        LITTLE QUIAPO RESTAURANT                                           0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                       0
# 507219        TARGET STORE # T-2079                                              0
#
#                                             Facility_Type_Cafeteria  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                          0
# 507211        PANERA BREAD                                        0
# 507212        LITTLE QUIAPO RESTAURANT                            0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                        0
# 507219        TARGET STORE # T-2079                               0
#
#                                             Facility_Type_Catering  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                         0
# 507211        PANERA BREAD                                       0
# 507212        LITTLE QUIAPO RESTAURANT                           0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                       0
# 507219        TARGET STORE # T-2079                              0
#
#                                             Facility_Type_Children's Services Facility  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                             0
# 507211        PANERA BREAD                                                           0
# 507212        LITTLE QUIAPO RESTAURANT                                               0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                           0
# 507219        TARGET STORE # T-2079                                                  0
#
#                                             Facility_Type_Coffee shop  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                            0
# 507211        PANERA BREAD                                          0
# 507212        LITTLE QUIAPO RESTAURANT                              0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                          0
# 507219        TARGET STORE # T-2079                                 0
#
#                                             Facility_Type_Commissary  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                           0
# 507211        PANERA BREAD                                         0
# 507212        LITTLE QUIAPO RESTAURANT                             0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                         0
# 507219        TARGET STORE # T-2079                                0
#
#                                             Facility_Type_DAYCARE  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                        0
# 507211        PANERA BREAD                                      0
# 507212        LITTLE QUIAPO RESTAURANT                          0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                      0
# 507219        TARGET STORE # T-2079                             0
#
#                                             Facility_Type_DAYCARE 1023  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                             0
# 507211        PANERA BREAD                                           0
# 507212        LITTLE QUIAPO RESTAURANT                               0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                           0
# 507219        TARGET STORE # T-2079                                  0
#
#                                             Facility_Type_DRUG STORE/GROCERY  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                   0
# 507211        PANERA BREAD                                                 0
# 507212        LITTLE QUIAPO RESTAURANT                                     0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                 0
# 507219        TARGET STORE # T-2079                                        0
#
#                                             Facility_Type_DRUG/FOOD STORE  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                0
# 507211        PANERA BREAD                                              0
# 507212        LITTLE QUIAPO RESTAURANT                                  0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                              0
# 507219        TARGET STORE # T-2079                                     0
#
#                                             Facility_Type_DRUG/GROCERY STORE  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                   0
# 507211        PANERA BREAD                                                 0
# 507212        LITTLE QUIAPO RESTAURANT                                     0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                 0
# 507219        TARGET STORE # T-2079                                        0
#
#                                             Facility_Type_Daycare (2 - 6 Years)  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                      0
# 507211        PANERA BREAD                                                    0
# 507212        LITTLE QUIAPO RESTAURANT                                        0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                    0
# 507219        TARGET STORE # T-2079                                           0
#
#                                             Facility_Type_Daycare (2 Years)  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                  0
# 507211        PANERA BREAD                                                0
# 507212        LITTLE QUIAPO RESTAURANT                                    0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                0
# 507219        TARGET STORE # T-2079                                       0
#
#                                             Facility_Type_Daycare (Under 2 Years)  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                        0
# 507211        PANERA BREAD                                                      0
# 507212        LITTLE QUIAPO RESTAURANT                                          0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                      0
# 507219        TARGET STORE # T-2079                                             0
#
#                                             Facility_Type_Daycare Above and Under 2 Years  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                                0
# 507211        PANERA BREAD                                                              0
# 507212        LITTLE QUIAPO RESTAURANT                                                  0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                              0
# 507219        TARGET STORE # T-2079                                                     0
#
#                                             Facility_Type_Daycare Combo 1586  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                   0
# 507211        PANERA BREAD                                                 0
# 507212        LITTLE QUIAPO RESTAURANT                                     0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                 0
# 507219        TARGET STORE # T-2079                                        0
#
#                                             Facility_Type_Deli  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                     0
# 507211        PANERA BREAD                                   0
# 507212        LITTLE QUIAPO RESTAURANT                       0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                   0
# 507219        TARGET STORE # T-2079                          0
#
#                                             Facility_Type_FAST FOOD/LIQUOR  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                 0
# 507211        PANERA BREAD                                               0
# 507212        LITTLE QUIAPO RESTAURANT                                   0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                               0
# 507219        TARGET STORE # T-2079                                      0
#
#                                             Facility_Type_FITNESS CENTER  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                               0
# 507211        PANERA BREAD                                             0
# 507212        LITTLE QUIAPO RESTAURANT                                 0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                             0
# 507219        TARGET STORE # T-2079                                    0
#
#                                             Facility_Type_GAS STATION  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                            0
# 507211        PANERA BREAD                                          0
# 507212        LITTLE QUIAPO RESTAURANT                              0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                          0
# 507219        TARGET STORE # T-2079                                 0
#
#                                             Facility_Type_GAS STATION /GROCERY  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                     0
# 507211        PANERA BREAD                                                   0
# 507212        LITTLE QUIAPO RESTAURANT                                       0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                   0
# 507219        TARGET STORE # T-2079                                          0
#
#                                             Facility_Type_GAS STATION/GROCERY  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                    0
# 507211        PANERA BREAD                                                  0
# 507212        LITTLE QUIAPO RESTAURANT                                      0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                  0
# 507219        TARGET STORE # T-2079                                         0
#
#                                             Facility_Type_GAS STATION/MINI MART  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                      0
# 507211        PANERA BREAD                                                    0
# 507212        LITTLE QUIAPO RESTAURANT                                        0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                    0
# 507219        TARGET STORE # T-2079                                           0
#
#                                             Facility_Type_GAS STATION/RESTAURANT  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                       0
# 507211        PANERA BREAD                                                     0
# 507212        LITTLE QUIAPO RESTAURANT                                         0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                     0
# 507219        TARGET STORE # T-2079                                            0
#
#                                             Facility_Type_GROCERY AND BUTCHER  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                    0
# 507211        PANERA BREAD                                                  0
# 507212        LITTLE QUIAPO RESTAURANT                                      0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                  0
# 507219        TARGET STORE # T-2079                                         0
#
#                                             Facility_Type_GROCERY STORE / GAS STATION  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                            0
# 507211        PANERA BREAD                                                          0
# 507212        LITTLE QUIAPO RESTAURANT                                              0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                          0
# 507219        TARGET STORE # T-2079                                                 0
#
#                                             Facility_Type_GROCERY STORE/ RESTAURANT  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                          0
# 507211        PANERA BREAD                                                        0
# 507212        LITTLE QUIAPO RESTAURANT                                            0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                        0
# 507219        TARGET STORE # T-2079                                               0
#
#                                             Facility_Type_GROCERY STORE/BAKERY  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                     0
# 507211        PANERA BREAD                                                   0
# 507212        LITTLE QUIAPO RESTAURANT                                       0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                   0
# 507219        TARGET STORE # T-2079                                          0
#
#                                             Facility_Type_GROCERY STORE/COOKING SCHOOL  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                             0
# 507211        PANERA BREAD                                                           0
# 507212        LITTLE QUIAPO RESTAURANT                                               0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                           0
# 507219        TARGET STORE # T-2079                                                  0
#
#                                             Facility_Type_GROCERY STORE/RESTAURANT  \
# ...
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                    0
# 507219        TARGET STORE # T-2079                                           0
#
#                                             LICENSE_DESCRIPTION_Navy Pier Kiosk License  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                              0
# 507211        PANERA BREAD                                                            0
# 507212        LITTLE QUIAPO RESTAURANT                                                0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                            0
# 507219        TARGET STORE # T-2079                                                   0
#
#                                             LICENSE_DESCRIPTION_Navy Pier Vendor (Food)  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                              0
# 507211        PANERA BREAD                                                            0
# 507212        LITTLE QUIAPO RESTAURANT                                                0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                            0
# 507219        TARGET STORE # T-2079                                                   0
#
#                                             LICENSE_DESCRIPTION_Not-For-Profit Club  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                          0
# 507211        PANERA BREAD                                                        0
# 507212        LITTLE QUIAPO RESTAURANT                                            0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                        0
# 507219        TARGET STORE # T-2079                                               0
#
#                                             LICENSE_DESCRIPTION_Outdoor Patio  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                    0
# 507211        PANERA BREAD                                                  0
# 507212        LITTLE QUIAPO RESTAURANT                                      0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                  0
# 507219        TARGET STORE # T-2079                                         0
#
#                                             LICENSE_DESCRIPTION_Package Goods  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                    0
# 507211        PANERA BREAD                                                  0
# 507212        LITTLE QUIAPO RESTAURANT                                      0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                  0
# 507219        TARGET STORE # T-2079                                         0
#
#                                             LICENSE_DESCRIPTION_Public Garage  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                    0
# 507211        PANERA BREAD                                                  0
# 507212        LITTLE QUIAPO RESTAURANT                                      0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                  0
# 507219        TARGET STORE # T-2079                                         0
#
#                                             LICENSE_DESCRIPTION_Public Place of Amusement  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                                0
# 507211        PANERA BREAD                                                              0
# 507212        LITTLE QUIAPO RESTAURANT                                                  0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                              0
# 507219        TARGET STORE # T-2079                                                     0
#
#                                             LICENSE_DESCRIPTION_Regulated Business License  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                                 0
# 507211        PANERA BREAD                                                               0
# 507212        LITTLE QUIAPO RESTAURANT                                                   0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                               0
# 507219        TARGET STORE # T-2079                                                      0
#
#                                             LICENSE_DESCRIPTION_Residential Real Estate Developer  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                                    0
# 507211        PANERA BREAD                                                                  0
# 507212        LITTLE QUIAPO RESTAURANT                                                      0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                                  0
# 507219        TARGET STORE # T-2079                                                         0
#
#                                             LICENSE_DESCRIPTION_Retail Food - Seasonal Lakefront Food Establishment  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                                    0
# 507211        PANERA BREAD                                                                  0
# 507212        LITTLE QUIAPO RESTAURANT                                                      0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                                  0
# 507219        TARGET STORE # T-2079                                                         0
#
#                                             LICENSE_DESCRIPTION_Retail Food Est.-Supplemental License for Dog-Friendly Areas  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                                    0
# 507211        PANERA BREAD                                                                  0
# 507212        LITTLE QUIAPO RESTAURANT                                                      0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                                  0
# 507219        TARGET STORE # T-2079                                                         0
#
#                                             LICENSE_DESCRIPTION_Retail Food Establishment  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                                1
# 507211        PANERA BREAD                                                              1
# 507212        LITTLE QUIAPO RESTAURANT                                                  1
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                              1
# 507219        TARGET STORE # T-2079                                                     1
#
#                                             LICENSE_DESCRIPTION_Scavenger, Private  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                         0
# 507211        PANERA BREAD                                                       0
# 507212        LITTLE QUIAPO RESTAURANT                                           0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                       0
# 507219        TARGET STORE # T-2079                                              0
#
#                                             LICENSE_DESCRIPTION_Shared Kitchen User  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                          0
# 507211        PANERA BREAD                                                        0
# 507212        LITTLE QUIAPO RESTAURANT                                            0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                        0
# 507219        TARGET STORE # T-2079                                               0
#
#                                             LICENSE_DESCRIPTION_Special Event Food  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                         0
# 507211        PANERA BREAD                                                       0
# 507212        LITTLE QUIAPO RESTAURANT                                           0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                       0
# 507219        TARGET STORE # T-2079                                              0
#
#                                             LICENSE_DESCRIPTION_Tavern  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                             0
# 507211        PANERA BREAD                                           0
# 507212        LITTLE QUIAPO RESTAURANT                               0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                           0
# 507219        TARGET STORE # T-2079                                  0
#
#                                             LICENSE_DESCRIPTION_Tire Facilty Class I (100 - 1,000 Tires)  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                                    0
# 507211        PANERA BREAD                                                                  0
# 507212        LITTLE QUIAPO RESTAURANT                                                      0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                                  0
# 507219        TARGET STORE # T-2079                                                         0
#
#                                             LICENSE_DESCRIPTION_Tobacco  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                              0
# 507211        PANERA BREAD                                            0
# 507212        LITTLE QUIAPO RESTAURANT                                0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                            0
# 507219        TARGET STORE # T-2079                                   0
#
#                                             LICENSE_DESCRIPTION_Wholesale Food Establishment  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                                   0
# 507211        PANERA BREAD                                                                 0
# 507212        LITTLE QUIAPO RESTAURANT                                                     0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                                 0
# 507219        TARGET STORE # T-2079                                                        0
#
#                                             LICENSE_DESCRIPTION_Wrigley Field  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                    0
# 507211        PANERA BREAD                                                  0
# 507212        LITTLE QUIAPO RESTAURANT                                      0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                  0
# 507219        TARGET STORE # T-2079                                         0
#
#                                             APPLICATION_TYPE_C_EXPA  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                          0
# 507211        PANERA BREAD                                        0
# 507212        LITTLE QUIAPO RESTAURANT                            0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                        0
# 507219        TARGET STORE # T-2079                               0
#
#                                             APPLICATION_TYPE_C_LOC  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                         0
# 507211        PANERA BREAD                                       0
# 507212        LITTLE QUIAPO RESTAURANT                           0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                       0
# 507219        TARGET STORE # T-2079                              0
#
#                                             APPLICATION_TYPE_ISSUE  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                         0
# 507211        PANERA BREAD                                       0
# 507212        LITTLE QUIAPO RESTAURANT                           0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                       0
# 507219        TARGET STORE # T-2079                              0
#
#                                             APPLICATION_TYPE_RENEW  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                         1
# 507211        PANERA BREAD                                       1
# 507212        LITTLE QUIAPO RESTAURANT                           1
# 507216        SERGIO'S TAQUERIA PIZZA INC.                       1
# 507219        TARGET STORE # T-2079                              1
#
#                                             age_groups_middle  age_groups_old  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                    0               1
# 507211        PANERA BREAD                                  1               0
# 507212        LITTLE QUIAPO RESTAURANT                      1               0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                  1               0
# 507219        TARGET STORE # T-2079                         1               0
#
#                                             age_groups_young
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                   0
# 507211        PANERA BREAD                                 0
# 507212        LITTLE QUIAPO RESTAURANT                     0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                 0
# 507219        TARGET STORE # T-2079                        0

# %% [markdown]
# ### Look for correlations

# %%
chicago_inspections_2011_to_2013.corr(method='pearson', min_periods=1)
# Out:
#                                              pastFail  pastCritical  \
# pastFail                                     1.000000      0.279907
# pastCritical                                 0.279907      1.000000
# pastSerious                                  0.774943      0.313040
# pastMinor                                    0.370640      0.325807
# timeSinceLast                               -0.319734     -0.217906
# firstRecord                                 -0.356773     -0.261541
# POLICE_DISTRICT                              0.019537      0.041286
# ageAtInspection                              0.063618      0.043256
# consumption_on_premises_incidental_activity  0.028218      0.013402
# tobacco                                     -0.024086     -0.033215
# package_goods                               -0.028876     -0.014576
# outdoor_patio                                0.015291      0.011069
# public_place_of_amusement                    0.013804      0.007356
# limited_business_license                    -0.030412     -0.013769
# childrens_services_facility_license         -0.038240     -0.034756
# tavern                                       0.002491     -0.006850
# regulated_business_license                  -0.000265     -0.005204
# filling_station                             -0.025197     -0.021757
# caterers_liquor_license                     -0.007206      0.004578
# mobile_food_license                         -0.006469     -0.008971
# precipIntensity                              0.010965      0.009329
# temperatureMax                              -0.003179      0.016216
# windSpeed                                   -0.042200     -0.035695
# humidity                                     0.013578      0.018796
# heat_burglary                                0.027146      0.014806
# heat_garbage                                 0.027364     -0.011436
# heat_sanitation                              0.004176      0.023169
# age                                          0.063026      0.042173
#
#                                              pastSerious  pastMinor  \
# pastFail                                        0.774943   0.370640
# pastCritical                                    0.313040   0.325807
# pastSerious                                     1.000000   0.410094
# pastMinor                                       0.410094   1.000000
# timeSinceLast                                  -0.305562  -0.725742
# firstRecord                                    -0.365730  -0.828602
# POLICE_DISTRICT                                 0.025437   0.022207
# ageAtInspection                                 0.054494   0.162585
# consumption_on_premises_incidental_activity     0.024672   0.032901
# tobacco                                        -0.022797  -0.073644
# package_goods                                  -0.017841  -0.040499
# outdoor_patio                                   0.009254   0.007485
# public_place_of_amusement                       0.015981   0.004168
# limited_business_license                       -0.031086  -0.081263
# childrens_services_facility_license            -0.039261  -0.083594
# tavern                                         -0.016038  -0.005138
# regulated_business_license                     -0.005063  -0.000950
# filling_station                                -0.025875  -0.051969
# caterers_liquor_license                        -0.008620   0.004860
# mobile_food_license                            -0.009020  -0.012303
# precipIntensity                                 0.012799   0.007173
# temperatureMax                                  0.001241  -0.008930
# windSpeed                                      -0.053632  -0.067570
# humidity                                        0.023330   0.036705
# heat_burglary                                   0.032342  -0.033242
# heat_garbage                                    0.020384   0.007690
# heat_sanitation                                 0.027281  -0.022529
# age                                             0.054003   0.161204
#
#                                              timeSinceLast  firstRecord  \
# pastFail                                         -0.319734    -0.356773
# pastCritical                                     -0.217906    -0.261541
# pastSerious                                      -0.305562    -0.365730
# pastMinor                                        -0.725742    -0.828602
# timeSinceLast                                     1.000000     0.904231
# firstRecord                                       0.904231     1.000000
# POLICE_DISTRICT                                   0.022324     0.017136
# ageAtInspection                                  -0.140851    -0.171433
# consumption_on_premises_incidental_activity      -0.025910    -0.020656
# tobacco                                           0.113073     0.107931
# package_goods                                     0.055232     0.055717
# outdoor_patio                                    -0.002182    -0.002295
# public_place_of_amusement                         0.000619    -0.000257
# limited_business_license                          0.091839     0.099463
# childrens_services_facility_license               0.079394     0.091944
# tavern                                            0.006609     0.010458
# regulated_business_license                       -0.003161     0.002249
# filling_station                                   0.062396     0.063072
# caterers_liquor_license                          -0.000855    -0.000697
# mobile_food_license                               0.009077     0.012669
# precipIntensity                                  -0.008515    -0.002827
# temperatureMax                                    0.036889     0.019771
# windSpeed                                         0.030688     0.082166
# humidity                                         -0.004858    -0.042371
# heat_burglary                                     0.079579     0.069799
# heat_garbage                                      0.059509     0.061113
# heat_sanitation                                   0.080246     0.066862
# age                                              -0.140670    -0.170056
#
#                                              POLICE_DISTRICT  ageAtInspection  \
# pastFail                                            0.019537         0.063618
# pastCritical                                        0.041286         0.043256
# pastSerious                                         0.025437         0.054494
# pastMinor                                           0.022207         0.162585
# timeSinceLast                                       0.022324        -0.140851
# firstRecord                                         0.017136        -0.171433
# POLICE_DISTRICT                                     1.000000         0.019036
# ageAtInspection                                     0.019036         1.000000
# consumption_on_premises_incidental_activity         0.058356         0.062877
# tobacco                                            -0.030443         0.047559
# package_goods                                       0.004616         0.079227
# outdoor_patio                                       0.030362         0.008186
# public_place_of_amusement                           0.020131         0.017748
# limited_business_license                           -0.016955         0.037944
# childrens_services_facility_license                -0.016314         0.001114
# tavern                                              0.033367         0.067508
# regulated_business_license                          0.029280         0.036390
# filling_station                                    -0.008980        -0.006086
# caterers_liquor_license                            -0.018387         0.002951
# mobile_food_license                                 0.006053        -0.031096
# precipIntensity                                    -0.010020         0.010530
# temperatureMax                                      0.018117         0.011573
# windSpeed                                          -0.020507        -0.010497
# humidity                                           -0.006847         0.008439
# heat_burglary                                       0.067322        -0.033194
# heat_garbage                                        0.143206        -0.019431
# heat_sanitation                                     0.100916        -0.033107
# age                                                 0.018910         0.996895
#
#                                              consumption_on_premises_incidental_activity  \
# pastFail                                                                        0.028218
# pastCritical                                                                    0.013402
# pastSerious                                                                     0.024672
# pastMinor                                                                       0.032901
# timeSinceLast                                                                  -0.025910
# firstRecord                                                                    -0.020656
# POLICE_DISTRICT                                                                 0.058356
# ageAtInspection                                                                 0.062877
# consumption_on_premises_incidental_activity                                     1.000000
# tobacco                                                                        -0.045482
# package_goods                                                                  -0.027439
# outdoor_patio                                                                   0.304353
# public_place_of_amusement                                                       0.271189
# limited_business_license                                                       -0.011431
# childrens_services_facility_license                                            -0.060194
# tavern                                                                         -0.030413
# regulated_business_license                                                      0.057758
# filling_station                                                                -0.040511
# caterers_liquor_license                                                         0.165447
# mobile_food_license                                                             0.008199
# precipIntensity                                                                -0.007067
# temperatureMax                                                                  0.031425
# windSpeed                                                                      -0.008798
# humidity                                                                       -0.006341
# heat_burglary                                                                   0.033937
# heat_garbage                                                                   -0.086438
# heat_sanitation                                                                -0.006729
# age                                                                             0.062391
#
#                                               tobacco  package_goods  \
# pastFail                                    -0.024086      -0.028876
# pastCritical                                -0.033215      -0.014576
# pastSerious                                 -0.022797      -0.017841
# pastMinor                                   -0.073644      -0.040499
# timeSinceLast                                0.113073       0.055232
# firstRecord                                  0.107931       0.055717
# POLICE_DISTRICT                             -0.030443       0.004616
# ageAtInspection                              0.047559       0.079227
# consumption_on_premises_incidental_activity -0.045482      -0.027439
# tobacco                                      1.000000       0.495342
# package_goods                                0.495342       1.000000
# outdoor_patio                               -0.002486      -0.004888
# public_place_of_amusement                    0.027239      -0.016399
# limited_business_license                     0.420337       0.240186
# childrens_services_facility_license         -0.052968      -0.033786
# tavern                                       0.023254      -0.010228
# regulated_business_license                  -0.021119       0.007795
# filling_station                              0.355764      -0.019712
# caterers_liquor_license                     -0.009487       0.010693
# mobile_food_license                         -0.013672      -0.008721
# precipIntensity                              0.014196      -0.005451
# temperatureMax                               0.000112      -0.011088
# windSpeed                                   -0.006407      -0.003773
# humidity                                     0.022295       0.011728
# heat_burglary                                0.056906       0.010542
# heat_garbage                                 0.104048       0.021516
# heat_sanitation                              0.068242       0.028832
# age                                          0.048449       0.080197
#
#                                              outdoor_patio  \
# pastFail                                          0.015291
# pastCritical                                      0.011069
# pastSerious                                       0.009254
# pastMinor                                         0.007485
# timeSinceLast                                    -0.002182
# firstRecord                                      -0.002295
# POLICE_DISTRICT                                   0.030362
# ageAtInspection                                   0.008186
# consumption_on_premises_incidental_activity       0.304353
# tobacco                                          -0.002486
# package_goods                                    -0.004888
# outdoor_patio                                     1.000000
# public_place_of_amusement                         0.174406
# limited_business_license                          0.004310
# childrens_services_facility_license              -0.023201
# tavern                                            0.140634
# regulated_business_license                        0.032195
# filling_station                                  -0.015614
# caterers_liquor_license                           0.128552
# mobile_food_license                              -0.005989
# precipIntensity                                  -0.015366
# temperatureMax                                    0.020622
# windSpeed                                        -0.005397
# humidity                                         -0.022726
# heat_burglary                                     0.025731
# heat_garbage                                     -0.044712
# heat_sanitation                                  -0.004144
# age                                               0.007367
#
#                                              public_place_of_amusement  \
# pastFail                                                      0.013804
# pastCritical                                                  0.007356
# pastSerious                                                   0.015981
# pastMinor                                                     0.004168
# timeSinceLast                                                 0.000619
# firstRecord                                                  -0.000257
# POLICE_DISTRICT                                               0.020131
# ageAtInspection                                               0.017748
# consumption_on_premises_incidental_activity                   0.271189
# tobacco                                                       0.027239
# package_goods                                                -0.016399
# outdoor_patio                                                 0.174406
# public_place_of_amusement                                     1.000000
# limited_business_license                                      0.041919
# childrens_services_facility_license                          -0.024060
# tavern                                                        0.174622
# regulated_business_license                                    0.038359
# filling_station                                              -0.016193
# caterers_liquor_license                                       0.097939
# mobile_food_license                                          -0.006210
# precipIntensity                                               0.002205
# temperatureMax                                                0.008261
# windSpeed                                                    -0.014430
# humidity                                                      0.008438
# heat_burglary                                                -0.001081
# heat_garbage                                                 -0.052665
# heat_sanitation                                              -0.012071
# age                                                           0.017407
#
#                                              limited_business_license  \
# pastFail                                                    -0.030412
# pastCritical                                                -0.013769
# pastSerious                                                 -0.031086
# pastMinor                                                   -0.081263
# timeSinceLast                                                0.091839
# firstRecord                                                  0.099463
# POLICE_DISTRICT                                             -0.016955
# ageAtInspection                                              0.037944
# consumption_on_premises_incidental_activity                 -0.011431
# tobacco                                                      0.420337
# package_goods                                                0.240186
# outdoor_patio                                                0.004310
# public_place_of_amusement                                    0.041919
# limited_business_license                                     1.000000
# childrens_services_facility_license                          0.025882
# tavern                                                      -0.001583
# regulated_business_license                                   0.056607
# filling_station                                              0.218628
# caterers_liquor_license                                      0.027301
# mobile_food_license                                         -0.011905
# precipIntensity                                              0.011315
# temperatureMax                                              -0.006591
# windSpeed                                                    0.013602
# humidity                                                     0.001377
# heat_burglary                                                0.019608
# heat_garbage                                                 0.042720
# heat_sanitation                                              0.020984
# age                                                          0.040054
#
#                                              childrens_services_facility_license  \
# pastFail                                                               -0.038240
# pastCritical                                                           -0.034756
# pastSerious                                                            -0.039261
# pastMinor                                                              -0.083594
# timeSinceLast                                                           0.079394
# firstRecord                                                             0.091944
# POLICE_DISTRICT                                                        -0.016314
# ageAtInspection                                                         0.001114
# consumption_on_premises_incidental_activity                            -0.060194
# tobacco                                                                -0.052968
# package_goods                                                          -0.033786
# outdoor_patio                                                          -0.023201
# public_place_of_amusement                                              -0.024060
# limited_business_license                                                0.025882
# childrens_services_facility_license                                     1.000000
# tavern                                                                 -0.022007
# regulated_business_license                                             -0.019068
# filling_station                                                        -0.019168
# caterers_liquor_license                                                -0.015738
# mobile_food_license                                                    -0.007352
# precipIntensity                                                        -0.018729
# temperatureMax                                                         -0.008470
# windSpeed                                                               0.035750
# humidity                                                               -0.032381
# heat_burglary                                                           0.032762
# heat_garbage                                                            0.081144
# heat_sanitation                                                         0.024059
# age                                                                     0.001685
#
#                                                tavern  \
# pastFail                                     0.002491
# pastCritical                                -0.006850
# pastSerious                                 -0.016038
# pastMinor                                   -0.005138
# timeSinceLast                                0.006609
# firstRecord                                  0.010458
# POLICE_DISTRICT                              0.033367
# ageAtInspection                              0.067508
# consumption_on_premises_incidental_activity -0.030413
# tobacco                                      0.023254
# package_goods                               -0.010228
# outdoor_patio                                0.140634
# public_place_of_amusement                    0.174622
# limited_business_license                    -0.001583
# childrens_services_facility_license         -0.022007
# tavern                                       1.000000
# regulated_business_license                   0.008095
# filling_station                             -0.014811
# caterers_liquor_license                      0.020898
# mobile_food_license                         -0.005681
# precipIntensity                             -0.013866
# temperatureMax                               0.005141
# windSpeed                                   -0.005967
# humidity                                    -0.007479
# heat_burglary                               -0.006181
# heat_garbage                                -0.015004
# heat_sanitation                              0.000998
# age                                          0.066955
#
#                                              regulated_business_license  \
# pastFail                                                      -0.000265
# pastCritical                                                  -0.005204
# pastSerious                                                   -0.005063
# pastMinor                                                     -0.000950
# timeSinceLast                                                 -0.003161
# firstRecord                                                    0.002249
# POLICE_DISTRICT                                                0.029280
# ageAtInspection                                                0.036390
# consumption_on_premises_incidental_activity                    0.057758
# tobacco                                                       -0.021119
# package_goods                                                  0.007795
# outdoor_patio                                                  0.032195
# public_place_of_amusement                                      0.038359
# limited_business_license                                       0.056607
# childrens_services_facility_license                           -0.019068
# tavern                                                         0.008095
# regulated_business_license                                     1.000000
# filling_station                                               -0.012833
# caterers_liquor_license                                        0.002128
# mobile_food_license                                           -0.004922
# precipIntensity                                               -0.008771
# temperatureMax                                                -0.016867
# windSpeed                                                      0.007460
# humidity                                                      -0.012388
# heat_burglary                                                 -0.007969
# heat_garbage                                                  -0.036590
# heat_sanitation                                               -0.011756
# age                                                            0.037009
#
#                                              filling_station  \
# pastFail                                           -0.025197
# pastCritical                                       -0.021757
# pastSerious                                        -0.025875
# pastMinor                                          -0.051969
# timeSinceLast                                       0.062396
# firstRecord                                         0.063072
# POLICE_DISTRICT                                    -0.008980
# ageAtInspection                                    -0.006086
# consumption_on_premises_incidental_activity        -0.040511
# tobacco                                             0.355764
# package_goods                                      -0.019712
# outdoor_patio                                      -0.015614
# public_place_of_amusement                          -0.016193
# limited_business_license                            0.218628
# childrens_services_facility_license                -0.019168
# tavern                                             -0.014811
# regulated_business_license                         -0.012833
# filling_station                                     1.000000
# caterers_liquor_license                            -0.010592
# mobile_food_license                                -0.004948
# precipIntensity                                     0.007134
# temperatureMax                                      0.011806
# windSpeed                                          -0.006492
# humidity                                            0.017908
# heat_burglary                                       0.003759
# heat_garbage                                        0.045346
# heat_sanitation                                     0.007637
# age                                                -0.005405
#
#                                              caterers_liquor_license  \
# pastFail                                                   -0.007206
# pastCritical                                                0.004578
# pastSerious                                                -0.008620
# pastMinor                                                   0.004860
# timeSinceLast                                              -0.000855
# firstRecord                                                -0.000697
# POLICE_DISTRICT                                            -0.018387
# ageAtInspection                                             0.002951
# consumption_on_premises_incidental_activity                 0.165447
# tobacco                                                    -0.009487
# package_goods                                               0.010693
# outdoor_patio                                               0.128552
# public_place_of_amusement                                   0.097939
# limited_business_license                                    0.027301
# childrens_services_facility_license                        -0.015738
# tavern                                                      0.020898
# regulated_business_license                                  0.002128
# filling_station                                            -0.010592
# caterers_liquor_license                                     1.000000
# mobile_food_license                                         0.012186
# precipIntensity                                            -0.007988
# temperatureMax                                              0.007729
# windSpeed                                                   0.000736
# humidity                                                   -0.000839
# heat_burglary                                              -0.013919
# heat_garbage                                               -0.051082
# heat_sanitation                                            -0.001442
# age                                                         0.004042
#
#                                              mobile_food_license  \
# pastFail                                               -0.006469
# pastCritical                                           -0.008971
# pastSerious                                            -0.009020
# pastMinor                                              -0.012303
# timeSinceLast                                           0.009077
# firstRecord                                             0.012669
# POLICE_DISTRICT                                         0.006053
# ageAtInspection                                        -0.031096
# consumption_on_premises_incidental_activity             0.008199
# tobacco                                                -0.013672
# package_goods                                          -0.008721
# outdoor_patio                                          -0.005989
# public_place_of_amusement                              -0.006210
# limited_business_license                               -0.011905
# childrens_services_facility_license                    -0.007352
# tavern                                                 -0.005681
# regulated_business_license                             -0.004922
# filling_station                                        -0.004948
# caterers_liquor_license                                 0.012186
# mobile_food_license                                     1.000000
# precipIntensity                                         0.004239
# temperatureMax                                          0.003842
# windSpeed                                               0.003515
# humidity                                               -0.011270
# heat_burglary                                           0.013688
# heat_garbage                                            0.025140
# heat_sanitation                                         0.003868
# age                                                    -0.031117
#
#                                              precipIntensity  temperatureMax  \
# pastFail                                            0.010965       -0.003179
# pastCritical                                        0.009329        0.016216
# pastSerious                                         0.012799        0.001241
# pastMinor                                           0.007173       -0.008930
# timeSinceLast                                      -0.008515        0.036889
# firstRecord                                        -0.002827        0.019771
# POLICE_DISTRICT                                    -0.010020        0.018117
# ageAtInspection                                     0.010530        0.011573
# consumption_on_premises_incidental_activity        -0.007067        0.031425
# tobacco                                             0.014196        0.000112
# package_goods                                      -0.005451       -0.011088
# outdoor_patio                                      -0.015366        0.020622
# public_place_of_amusement                           0.002205        0.008261
# limited_business_license                            0.011315       -0.006591
# childrens_services_facility_license                -0.018729       -0.008470
# tavern                                             -0.013866        0.005141
# regulated_business_license                         -0.008771       -0.016867
# filling_station                                     0.007134        0.011806
# caterers_liquor_license                            -0.007988        0.007729
# mobile_food_license                                 0.004239        0.003842
# precipIntensity                                     1.000000        0.150115
# temperatureMax                                      0.150115        1.000000
# windSpeed                                           0.062647       -0.291204
# humidity                                            0.425055       -0.289099
# heat_burglary                                       0.007991        0.011673
# heat_garbage                                        0.003968       -0.044019
# heat_sanitation                                    -0.009378       -0.096944
# age                                                 0.010493        0.009239
#
#                                              windSpeed  humidity  \
# pastFail                                     -0.042200  0.013578
# pastCritical                                 -0.035695  0.018796
# pastSerious                                  -0.053632  0.023330
# pastMinor                                    -0.067570  0.036705
# timeSinceLast                                 0.030688 -0.004858
# firstRecord                                   0.082166 -0.042371
# POLICE_DISTRICT                              -0.020507 -0.006847
# ageAtInspection                              -0.010497  0.008439
# consumption_on_premises_incidental_activity  -0.008798 -0.006341
# tobacco                                      -0.006407  0.022295
# package_goods                                -0.003773  0.011728
# outdoor_patio                                -0.005397 -0.022726
# public_place_of_amusement                    -0.014430  0.008438
# limited_business_license                      0.013602  0.001377
# childrens_services_facility_license           0.035750 -0.032381
# tavern                                       -0.005967 -0.007479
# regulated_business_license                    0.007460 -0.012388
# filling_station                              -0.006492  0.017908
# caterers_liquor_license                       0.000736 -0.000839
# mobile_food_license                           0.003515 -0.011270
# precipIntensity                               0.062647  0.425055
# temperatureMax                               -0.291204 -0.289099
# windSpeed                                     1.000000 -0.088199
# humidity                                     -0.088199  1.000000
# heat_burglary                                -0.010192 -0.003006
# heat_garbage                                  0.005283  0.018247
# heat_sanitation                               0.006933  0.049272
# age                                          -0.008509  0.007460
#
#                                              heat_burglary  heat_garbage  \
# pastFail                                          0.027146      0.027364
# pastCritical                                      0.014806     -0.011436
# pastSerious                                       0.032342      0.020384
# pastMinor                                        -0.033242      0.007690
# timeSinceLast                                     0.079579      0.059509
# firstRecord                                       0.069799      0.061113
# POLICE_DISTRICT                                   0.067322      0.143206
# ageAtInspection                                  -0.033194     -0.019431
# consumption_on_premises_incidental_activity       0.033937     -0.086438
# tobacco                                           0.056906      0.104048
# package_goods                                     0.010542      0.021516
# outdoor_patio                                     0.025731     -0.044712
# public_place_of_amusement                        -0.001081     -0.052665
# limited_business_license                          0.019608      0.042720
# childrens_services_facility_license               0.032762      0.081144
# tavern                                           -0.006181     -0.015004
# regulated_business_license                       -0.007969     -0.036590
# filling_station                                   0.003759      0.045346
# caterers_liquor_license                          -0.013919     -0.051082
# mobile_food_license                               0.013688      0.025140
# precipIntensity                                   0.007991      0.003968
# temperatureMax                                    0.011673     -0.044019
# windSpeed                                        -0.010192      0.005283
# humidity                                         -0.003006      0.018247
# heat_burglary                                     1.000000      0.326522
# heat_garbage                                      0.326522      1.000000
# heat_sanitation                                   0.415282      0.297624
# age                                              -0.033316     -0.018988
#
#                                              heat_sanitation       age
# pastFail                                            0.004176  0.063026
# pastCritical                                        0.023169  0.042173
# pastSerious                                         0.027281  0.054003
# pastMinor                                          -0.022529  0.161204
# timeSinceLast                                       0.080246 -0.140670
# firstRecord                                         0.066862 -0.170056
# POLICE_DISTRICT                                     0.100916  0.018910
# ageAtInspection                                    -0.033107  0.996895
# consumption_on_premises_incidental_activity        -0.006729  0.062391
# tobacco                                             0.068242  0.048449
# package_goods                                       0.028832  0.080197
# outdoor_patio                                      -0.004144  0.007367
# public_place_of_amusement                          -0.012071  0.017407
# limited_business_license                            0.020984  0.040054
# childrens_services_facility_license                 0.024059  0.001685
# tavern                                              0.000998  0.066955
# regulated_business_license                         -0.011756  0.037009
# filling_station                                     0.007637 -0.005405
# caterers_liquor_license                            -0.001442  0.004042
# mobile_food_license                                 0.003868 -0.031117
# precipIntensity                                    -0.009378  0.010493
# temperatureMax                                     -0.096944  0.009239
# windSpeed                                           0.006933 -0.008509
# humidity                                            0.049272  0.007460
# heat_burglary                                       0.415282 -0.033316
# heat_garbage                                        0.297624 -0.018988
# heat_sanitation                                     1.000000 -0.032009
# age                                                -0.032009  1.000000

# %%
X.shape
# Out:
# (15311, 2042)

# %%
cor_matrix = X.corr().abs()
upper_tri = cor_matrix.where(np.triu(np.ones(cor_matrix.shape),k=1).astype(np.bool))
to_drop = [column for column in upper_tri.columns if any(upper_tri[column] > 0.70)]
X.drop(to_drop, axis=1, inplace=True)

# %% [markdown]
# ## Fit Models & Validation

# %% [markdown]
# **Hint for Validation**: Try writing a for loop to use [`cross_val_score()`](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_val_score.html) to check for accuracy, precision, recall and f1 across all of your models.

# %%
# Set seed
np.random.seed(10)

X_train, X_validate, y_train, y_validate = train_test_split(X, y, train_size = .75, test_size = .25, 
                                                           stratify = y)

# %% [markdown]
# ### Model 1 - SVM

# %% [markdown]
# Support Vector Machines (SVM) is a supervised machine learning algorithm that employs a hyperplane to differentiate between different values of target classes. The hyperplane is optimized to maximize the distance between the classes during the training process, and it is then used to predict the classification of future data. SVM assumes the data are independent and identically distributed. SVM does well with high-dimensional datasets, an advantage, but requires a clearly delineated hyperparameter to predict well, which is not always possible to achieve. In this application, we found that after hyperparameter tuning, SVM was able to predict the validation set with very good accuracy. The downside of using SVM for this application was the extremely long computing time required.

# %% [markdown]
# #### Setting up the hyperparameter grid and SVM model

# %%
# Warning: SVM takes a very long time to run. Confusion matrix output is included as screenshot

# %%
param_grid = {'C' : (50, 10, 1.0, 0.1, 0.01),
               'gamma' : ['scale', 'auto']}

# create a model
svm = SVC()

# %%
svm_model = svm.fit(X_train, y_train.ravel())

svm_pred = svm_model.predict(X_validate)

# %%
def rmse(pred, actual):
    return np.sqrt(np.mean((pred - actual) ** 2))

# %% [markdown]
# #### Hyperparameter Tuning Using Grid Search for SVM

# %%
svm_grid_reg = GridSearchCV(svm_model, param_grid, cv=3, iid=False)
svm_grid_reg.fit(X_train, y_train.ravel())

best_index = np.argmax(svm_grid_reg.cv_results_["mean_test_score"])
best_svm_pred = svm_grid_reg.best_estimator_.predict(X_validate)

print(svm_grid_reg.cv_results_["params"][best_index])
print('Best CV R^2:', max(svm_grid_reg.cv_results_["mean_test_score"]))
print('Validation R^2:', svm_grid_reg.score(X_validate, y_validate))
print('Validation RMSE', rmse(best_svm_pred, y_validate))

# %% [markdown]
# ![Screen Shot 2020-11-20 at 4.55.40 PM.png](attachment:e46705b3-bd1b-4e78-b2d3-1e23dc637509.png)

# %%
svm_CV_score = cross_val_score(svm_grid_reg, X_validate, y_validate.ravel(), cv=3)

# %% [markdown]
# #### Finding best hyperparameters and re-fitting the model

# %%
#new SVM model with optimal hyperparameters

# new model with optimal hyperparameters
svm = SVC() #need to update with hyperparameters once run tuning above

#fit a model
svm_model = svm.fit(X_train, y_train.ravel())

#use fit to predict
svm_pred = svm_model.predict(X_validate)

# %%
cf_matrix = confusion_matrix(y_validate, svm_pred, normalize = "true")

df_cm = pd.DataFrame(cf_matrix, range(2),
                  range(2))

df_cm = df_cm.rename(index=str, columns={0: "Pass", 1: "Fail"})
df_cm.index = ["Pass", "Fail"]
plt.figure(figsize = (10,7))
sns.set(font_scale=1.4)#for label size
sns.heatmap(df_cm, 
           annot=True,
           annot_kws={"size": 16},
           fmt='g')

plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %% [markdown]
# ![Screen Shot 2020-11-20 at 4.53.57 PM.png](attachment:bbd0c66e-bc6c-476f-bffe-7c338b5b9abc.png)

# %% [markdown]
# #### Validation for SVM

# %%
range(len(svm_pred))

TP = 0
FP = 0
TN = 0
FN = 0

for i in range(len(svm_pred)): 
    if y_validate[i]==y_pred[i]==1:
       TP += 1
    if y_pred[i]==1 and y_validate[i]!=y_pred[i]:
       FP += 1
    if y_validate[i]==y_pred[i]==0:
       TN += 1
    if y_pred[i]==0 and y_pred[i]!=y_validate[i]:
       FN += 1

# %%
accuracy = (TP + TN)/(TP + TN + FP + FN)
print("Accuracy is", accuracy)

# %% [markdown]
# ![Screen Shot 2020-11-20 at 4.57.29 PM.png](attachment:6c434dce-6a61-44ff-918a-62d06266c3dd.png)

# %%
precision = TP/(TP + FP)
print("Precision is", precision)

# %%
# Precision returns a divide by zero error

# %%
recall = TP/(TP + FN)
print("Recall is", recall)

# %% [markdown]
# ![Screen Shot 2020-11-20 at 5.00.12 PM.png](attachment:7fc295e8-eb38-4933-b6de-3849660530e6.png)

# %% [markdown]
# ### Model 2 - Logistic Regression

# %% [markdown]
# Be sure to do the following:
#
# 1. Import the appropriate library from sklearn
# 2. Set up a hyperparameter grid (check out our previous labs to see how to do this)
# 3. Find the best hyperparameters, and then fit your model (using train/validation splits or cross-validation)

# %% [markdown]
# #### Hyperparameter Tuning Using Grid Search for Logistic Regression

# %% [markdown]
# Fit the logistic model.

# %%
# create a model
logit_reg = LogisticRegression()

# fit the model
logit_model = logit_reg.fit(X_train, y_train)

logit_pred = logit_model.predict(X_validate)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ec3c34f17699> in <module>
#       1 # create a model
# ----> 2 logit_reg = LogisticRegression()
#       3
#       4 # fit the model
#       5 logit_model = logit_reg.fit(X_train, y_train)
#
# NameError: name 'LogisticRegression' is not defined

# %% [markdown]
# Using GridSearchCV to search for optimal hyperparameters

# %%
param_grid = {'penalty': ['l1', 'l2', 'elasticnet'],
             'C': np.arange(.1, 1, .1),
               'fit_intercept': ['True', 'False'],
             'solver': ['liblinear', 'saga']}

logit_grid = GridSearchCV(logit_model, param_grid, cv=3, iid=False)
logit_grid.fit(X_train, y_train)

best_index = np.argmax(log_grid.cv_results_["mean_test_score"])
best_logit_pred = logit_grid.best_estimator_.predict(X_validate)

print(logit_grid.cv_results_["params"][best_index])
print('Validation Accuracy', accuracy_score(best_logit_pred, y_validate))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3950641262a5> in <module>
#       1 param_grid = {'penalty': ['l1', 'l2', 'elasticnet'],
# ----> 2              'C': np.arange(.1, 1, .1),
#       3                'fit_intercept': ['True', 'False'],
#       4              'solver': ['liblinear', 'saga']}
#       5
#
# NameError: name 'np' is not defined

# %%
# testing code to capture the output of a cell -- not sure what info I should supply instead of 'stuff'?

# %%capture cap --no-stderr
print 'stuff'
with open('output.txt', 'w') as f:
    f.write(cap.stdout)

# %% [markdown]
# #### Finding best hyperparameters and re-fitting the model

# %% [markdown]
# Best hyperparameters from our tuning show:
# 'C': 0.1, 'fit_intercept': 'True', 'penalty': 'l1', 'solver': 'saga'}

# %%
## Logistic (redone with best hyperparameters) ## 

#tried to refit with all optimal parameters but they did not produce a confusion matrix - might it be that
#the hyperparameters overfit the data? Ended up with C: 0.1 and fit_intercept: True hyperparameters and 
#eliminated the penalty and solver and that ran

# create the model 
logit_reg = LogisticRegression(C=0.1, fit_intercept = True, )  

# fit the model
logit_model = logit_reg.fit(X_train, y_train)

# use the model to make predictions
logit_pred = logit_model.predict(X_validate)

# %% [markdown]
# Confusion matrix to visualize how well we did with our predictions using the updated model that has been hyperparameterized

# %%
cf_matrix = confusion_matrix(y_validate, logit_pred, normalize = "true")

df_cm = pd.DataFrame(cf_matrix, range(2),
                  range(2))

df_cm = df_cm.rename(index=str, columns={0: "Pass", 1: "Fail"})
df_cm.index = ["Pass", "Fail"]
plt.figure(figsize = (10,7))
sns.set(font_scale=1.4)#for label size
sns.heatmap(df_cm, 
           annot=True,
           annot_kws={"size": 16},
           fmt='g')

plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %% [markdown]
# Logistic regression does a pretty good job predicting pass but a pretty terrible job predicting fails.

# %% [markdown]
# #### Validation for Logistic Regression

# %%
range(len(logit_pred))
# Out:
# range(0, 3828)

# %%
TP = 0
FP = 0
TN = 0
FN = 0

for i in range(len(logit_pred)): 
    if y_validate[i]==logit_pred[i]==1:
       TP += 1
    if logit_pred[i]==1 and y_validate[i]!=logit_pred[i]:
       FP += 1
    if y_validate[i]==logit_pred[i]==0:
       TN += 1
    if logit_pred[i]==0 and logit_pred[i]!=y_validate[i]:
       FN += 1

# %%
accuracy = (TP + TN)/(TP + TN + FP + FN)
print("Accuracy is", accuracy)
# Out:
# Accuracy is 0.7983281086729362

# %%
precision = TP/(TP + FP)
print("Precision is", precision)
# Out:
# Precision is 0.5

# %%
recall = TP/(TP + FN)
print("Recall is", recall)
# Out:
# Recall is 0.006476683937823834

# %%
f1 = 2 * (precision * recall)/(precision + recall)
print("F1 Score is", f1)
# Out:
# F1 Score is 0.012787723785166238

# %% [markdown]
# ### Model 3 - Decision Tree

# %% [markdown]
# Detail the basic logic and assumptions underlying each model, its
# pros/cons, and why it is a plausible choice for this problem.
#
# Set up a hyperparameter grid (check out our previous labs to see how to do this)
# Find the best hyperparameters, and then fit your model (using train/validation splits or cross-validation)
#
# Run the grid search to find the best hyperparameters
# Use cross-validation on the model with the best hyperparameters (this should be something like "grid.best_estimator_" assuming you've trained a GridSearchCV and assigned it as "grid") on X and y
# Use cross_val_score to get accuracy, precision, etc.

# %% [markdown]
# ##### About Decision trees:
#
# Decision trees use a series of if/then rules to infer from the data and predict the values of new variables.
#
# Pros: Decision trees are simple, do not require a lot of prior processing or data manipulation, and are very transparent: they're easy to validate, and to interpret.
#     They also don't make assumptions about the shape or form of the data.
#
# Cons: Decision trees can overfit the data, and can create biased trees if the data is not balanced.

# %% [markdown]
# #### Hyperparameter Tuning Using Grid Search for Decision Tree

# %%
# using grid search CV to fine tune hyperparameters

dt_classifier_test = tree.DecisionTreeClassifier()

param_grid = {'max_depth': [5, 10, 15],
             'min_samples_split': [2, 4, 6, 8, 10],
             'max_features': [5, 10, 15]}

# %%
dt_grid = GridSearchCV(dt_classifier_test, param_grid, cv = 3)
dt_grid.fit(X, y)
dt_grid
# Out:
# GridSearchCV(cv=3, estimator=DecisionTreeClassifier(),
#              param_grid={'max_depth': [5, 10, 15], 'max_features': [5, 10, 15],
#                          'min_samples_split': [2, 4, 6, 8, 10]})

# %%
print('Best max depth:', dt_grid.best_estimator_.get_params()['max_depth'])
print('Best min samples split:', dt_grid.best_estimator_.get_params()['min_samples_split'])
print('Best max leaf nodes:', dt_grid.best_estimator_.get_params()['max_leaf_nodes'])
# Out:
# Best max depth: 5
# Best min samples split: 6
# Best max leaf nodes: None

# %% [markdown]
# #### Finding best hyperparameters and re-fitting the model

# %%
dt_classifier = tree.DecisionTreeClassifier(criterion='gini',  # or 'entropy' for information gain
                       splitter='best',  # or 'random' for random best split
                       max_depth=5,  # how deep tree nodes can go
                       min_samples_split=6,  # samples needed to split node
                       min_samples_leaf=1,  # samples needed for a leaf
                       min_weight_fraction_leaf=0.0,  # weight of samples needed for a node
                       max_features=None,  # number of features to look for when splitting
                       max_leaf_nodes=None,  # max nodes
                       min_impurity_decrease=1e-07, #early stopping
                       random_state = 10) #random seed

dt_classifier = dt_classifier.fit(X_train, y_train)

# %%
print(dt_classifier.score(X_train, y_train))
# Out:
# 0.8036227466689889

# %%
print(dt_classifier.score(X_validate, y_validate))
# Out:
# 0.7938871473354232

# %%
dt_pred = dt_classifier.predict(X_validate)

# %%
cf_matrix = confusion_matrix(y_validate, dt_pred, normalize = "true")

df_cm = pd.DataFrame(cf_matrix, range(2),
                  range(2))

df_cm = df_cm.rename(index=str, columns={0: "<=50k", 1: ">50k"})
df_cm.index = ["<=50k", ">50k"]
plt.figure(figsize = (10,7))
sns.set(font_scale=1.4)#for label size
sns.heatmap(df_cm, 
           annot=True,
           annot_kws={"size": 16},
           fmt='g')

plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %% [markdown]
# #### Validation for Decision Tree

# %%
range(len(dt_pred))
# Out:
# range(0, 3828)

# %%
TP = 0
FP = 0
TN = 0
FN = 0

for i in range(len(dt_pred)): 
    if y_validate[i]==dt_pred[i]==1:
       TP += 1
    if dt_pred[i]==1 and y_validate[i]!=dt_pred[i]:
       FP += 1
    if y_validate[i]==dt_pred[i]==0:
       TN += 1
    if dt_pred[i]==0 and dt_pred[i]!=y_validate[i]:
       FN += 1

# %% [markdown]
# Accuracy:

# %%
accuracy = (TP + TN)/(TP + TN + FP + FN)
print("Accuracy is", accuracy)
# Out:
# Accuracy is 0.7938871473354232

# %% [markdown]
# Precision:

# %%
precision = TP/(TP + FP)
print("Precision is", precision)
# Out:
# Precision is 0.33962264150943394

# %% [markdown]
# Recall:

# %%
recall = TP/(TP + FN)
print("Recall is", recall)
# Out:
# Recall is 0.023316062176165803

# %%
# roc curve and auc

# split into train/test sets
# generate a no skill prediction (majority class)
ns_probs = [0 for _ in range(len(y_validate))]


# predict probabilities for dt
dt_probs = dt_classifier.predict_proba(X_validate)

# keep probabilities for the positive outcome only
dt_probs = dt_probs[:, 1]

# calculate scores
ns_auc = roc_auc_score(y_validate, ns_probs)
dt_auc = roc_auc_score(y_validate, dt_probs)

# summarize scores
print('No Skill: ROC AUC=%.3f' % (ns_auc))
print('Logistic: ROC AUC=%.3f' % (dt_auc))

# calculate roc curves
ns_fpr, ns_tpr, _ = roc_curve(y_validate, ns_probs)
dt_fpr, dt_tpr, _ = roc_curve(y_validate, dt_probs)

# plot the roc curve for the model
pyplot.plot(ns_fpr, ns_tpr, linestyle='--', label='No Skill')
pyplot.plot(dt_fpr, dt_tpr, marker='.', label='Decision Tree')
# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
# show the legend
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# No Skill: ROC AUC=0.500
# Logistic: ROC AUC=0.599

# %% [markdown]
# Which of these metrics would you want to prioritize when conducting predictive auditing in this context? Why?

# %% [markdown]
# ## Policy Simulation

# %% [markdown]
# ### Interpretable Machine Learning

# %% [markdown]
# **Hint**: Use tools like feature importance plots and coefficient plots

# %% [markdown]
# ### Model 2 - Logistic Regression

# %%
logit_data = pd.concat([pd.DataFrame(X.columns),pd.DataFrame(np.transpose(logit_model.coef_))], axis = 1)
logit_data.columns = ['Feature', 'Coefficient']
logit_data['abs_coef'] = abs(logit_data['Coefficient'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-a532344b0779> in <module>
# ----> 1 logit_data = pd.concat([pd.DataFrame(X.columns),pd.DataFrame(np.transpose(logit_model.coef_))], axis = 1)
#       2 logit_data.columns = ['Feature', 'Coefficient']
#       3 logit_data['abs_coef'] = abs(logit_data['Coefficient'])
#
# NameError: name 'logit_model' is not defined

# %%
sns.barplot(x="Coefficient", y="Feature", data=logit_data.nlargest(10, 'abs_coef')).set_title("Top Logit Coefficients")
plt.show()

# %% [markdown]
# ### Model 3 - Decision Tree

# %%
feat_importances = pd.concat([pd.DataFrame(X.columns),pd.DataFrame(np.transpose(dt_classifier.feature_importances_))], axis = 1)
feat_importances.columns = ["Feature", "Importance"]
sns.barplot(x = "Importance", y = "Feature", data = feat_importances.nlargest(10, 'Importance'))
plt.show()

# %% [markdown]
# ## Prioritize Audits

# %% [markdown]
# **Hint**: Look up the [`.predict()`](https://www.kite.com/python/docs/sklearn.linear_model.SGDRegressor.predict), [`.predict_proba()`](https://www.kite.com/python/docs/sklearn.linear_model.LogisticRegression.predict_proba), and [`.sample()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html) methods. Then:
# 1. Choose one of your models (or train a new simplified model or ensemble!) to predict outcomes and probabilities.
# 2. Order your audits by their probability of detecting a "Fail" score
# 3. Plot your distribution of pass/fail among the first 1000 observations in the dataset
# 4. Simulate random audits on the full chicago_2011_to_2013.csv dataset by picking 1000 observations at random

# %%
# Probability of failing:
dt_prob_fail = dt_probs
# we already sliced above


# Predicting the outcome
dt_outcome = dt_classifier.predict(X)
print(dt_outcome)

# adding these as columns to the dataframe
chicago_inspections_2011_to_2013['probabilities']=dt_prob_fail
chicago_inspections_2011_to_2013['predicted_outcome']=dt_outcome

# keep just the first 1000 rows, from this, discard rest
# & plot how well predicted restaurants that would fail: results, pred outcomes, etc
# final step: take overall dataset, sample 1000 randomly, compare the first 1000, versus the random sampling
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-9e57142eb0dd> in <module>
#       1 # Probability of failing:
# ----> 2 dt_prob_fail = dt_probs
#       3
#       4 # Predicting the outcome
#       5 dt_outcome = dt_classifier.predict(X)
#
# NameError: name 'dt_probs' is not defined

# %%
# sorting by probability of failing
chicago_inspections_2011_to_2013.sort_values(by = 'probabilities', ascending = False)

# %%
#selecting out the first 1000 rows
first_1000 = chicago_inspections_2011_to_2013.iloc[0:999]

# %%
#plot distribution
first_1000.loc[first_1000['predicted_outcome'] == 0]
first_1000.loc[first_1000['predicted_outcome'] == 1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'predicted_outcome'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-64-f2f012e0e92b> in <module>
#       1 #plot distribution
# ----> 2 chicago_inspections_2011_to_2013.loc[chicago_inspections_2011_to_2013['predicted_outcome'] == 0]
#       3 chicago_inspections_2011_to_2013.loc[chicago_inspections_2011_to_2013['predicted_outcome'] == 1]
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'predicted_outcome'

# %%
# predicting at random
data = chicago_inspections_2011_to_2013.iloc[0:1000], x = 'predicted_outcome_2', kind = 'count')

# %% [markdown]
# ### Predict on Data with Unseen Labels

# %%
# Fill in the code below with the X data you used for training
X_test = chicago_inspections_2014[chicago_inspections_2014.columns & ....columns]
